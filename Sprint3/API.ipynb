# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov 25 10:24:13 2020

@author: Juanes MejÃ­a
"""
#!pip install boto3
import boto3, requests
#boto3 es la libreria que establece la api

#toda cuenta tienen un key id y secrect key (usuario y contraseña). Para acceder a aws
session = boto3.Session(
    aws_access_key_id='AKIAIWFTBNET7VGWZOVA', #cuenta de juanes de la universidad
    aws_secret_access_key='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',
    region_name = 'us-east-1' #region tiene centro de computadores en varios lugares
)

# %%
rekognition = session.client('rekognition') #api de recognition
response = requests.get('https://www.dzoom.org.es/wp-content/uploads/2010/09/retrato-fondo-profundidad-campo-734x489.jpg')
response_content = response.content #genera un imagen de bits onda rgb para analizar la cara . mapa de bits
#cada api pide un formato especifico a como esta programado el api
#debe ser abnostico al lenguaje de programacion(si mando un dataframe en pandas de python a R no lo reconoce, tengo que mandar en un formato comun ej JSON)

rekognition_response = rekognition.detect_faces(Image={'Bytes': response_content}, Attributes=['ALL']) #hay metodos(detect face) , le doymapa de bytes y pido con atribute todo los atributos que le puedo sacar.  a
                           
print(rekognition_response) #devuelve un json.
#hay diccionarios dentro de los diccionarios
rekognition_response['FaceDetails']
# Out:
# {'FaceDetails': [{'BoundingBox': {'Width': 0.2196483612060547, 'Height': 0.438174307346344, 'Left': 0.43958255648612976, 'Top': 0.21694940328598022}, 'AgeRange': {'Low': 26, 'High': 40}, 'Smile': {'Value': False, 'Confidence': 50.36098861694336}, 'Eyeglasses': {'Value': False, 'Confidence': 99.90797424316406}, 'Sunglasses': {'Value': False, 'Confidence': 99.96299743652344}, 'Gender': {'Value': 'Female', 'Confidence': 99.96200561523438}, 'Beard': {'Value': False, 'Confidence': 99.79215240478516}, 'Mustache': {'Value': False, 'Confidence': 99.92831420898438}, 'EyesOpen': {'Value': True, 'Confidence': 69.74513244628906}, 'MouthOpen': {'Value': False, 'Confidence': 95.101318359375}, 'Emotions': [{'Type': 'HAPPY', 'Confidence': 56.52932357788086}, {'Type': 'CALM', 'Confidence': 41.75161361694336}, {'Type': 'SURPRISED', 'Confidence': 0.8820611238479614}, {'Type': 'SAD', 'Confidence': 0.333915114402771}, {'Type': 'DISGUSTED', 'Confidence': 0.2092355191707611}, {'Type': 'CONFUSED', 'Confiden
# ...

# %%
prob_smile=rekognition_response['FaceDetails'][0]['Smile']['Confidence']
#hay que saber cómo esta construido el json
# Out:
# 50.36098861694336

# %%
rekognition_response['FaceDetails'][0]['Emotions'][7]['Confidence']
# Out:
# 0.035292237997055054
